# %% [markdown]
# # ETL y ELT

# %% [markdown]
# ## Qué es ETL?

# %% [markdown]
# ETL es un proceso que se utiliza para mover, limpiar y estructurar datos desde una o más fuentes hasta un sistema de almacenamiento central.
#
# Sus siglas provienen de:
# - Extract (Extracción)
# - Transform (Transformación)
# - Load (Carga)
#
# Es un pilar fundamental en el mundo del análisis y la ingeniería de datos.

# %% [markdown]
# ## Para qué sirve el ETL?

# %% [markdown]
# - Centralizar información dispersa
# - Limpiar y validar datos inconsistentes
# - Transformar datos crudos en información útil
# - Preparar datos para reporting, dashboards o machine learning

# %% [markdown]
# ## Revisemos cada uno de las letras de la sigla ETL

# %% [markdown]
# ### E - Extract (Extracción)

# %% [markdown]
# Acá se toman los datos desde su fuente original, sin modificarlos, comúnmente de:
# - Bases de datos (SQL Server, PostgreSQL, Oracle)
# - Archivos planos (CSV, Excel, JSON)
# - APIs REST
# - Otros: ERP, CRM, sensores

# %% [markdown]
# ### T - Transform (Transformación)

# %% [markdown]
# Acá los datos crudos son transformados en información útil y coherente. El objetivo es producir datos estructurados, consistentes y listos para ser cargados. Algunas transformaciones comunes son:
# - **Limpieza de datos**: e.g. remover nulos, valores inválidos, duplicados
# - **Conversión de tipos de datos**: e.g. texto a fecha
# - **Unificación de formatos**: e.g. 2025/04/20 → 20-04-2025
# - **Cálculos y KPIs derivados**: e.g. márgenes de ganancia
# - **Reglas de negocio aplicadas**: e.g. definir categorías (rojo, amarillo, verde) según el márgen de ganancia
# - **Enriquecimiento con fuentes externas**: para expandir las capacidades de la data original

# %% [markdown]
# ### L - Load (Carga)

# %% [markdown]
# Acá se cargan los datos transformados al sistema destino.
#
# Los modos de carga son:
# - **Full Load**: se borra lo anterior y se carga todo nuevamente
# - **Append**: se agregan datos al final sin borrar lo anterior
# - **Incremental Load**: solo se cargan los cambios nuevos desde la última ejecución
#
# Los destinos comunes para guardar datos son:
# - **Data Warehouse**
# - **Data Marts** (subconjuntos temáticos)
# - **Bases SQL** optimizadas para BI

# %% [markdown]
# ## Qué es un Data Warehouse?

# %% [markdown]
# Un Data Warehouse es una base de datos diseñada específicamente para facilitar consultas y análisis de grandes volúmenes de información estructurada. Sus características más importantes son:
# - Almacena datos históricos
# - Está optimizado para consultas rápidas, no para transacciones
# - Integra información de múltiples fuentes
# - Soporta decisiones estratégicas, no procesos operativos
#
# Algunos ejemplos son: Snowflake, Amazon Redshift, Google BigQuery, Azure Synapse, bases de datos SQL.
#
# En el mundo real, un data warehouse contiene información proveniente de transacciones (e.g. compras, pagos, visitas, operaciones, etc.), pero no se usa para ejecutar esas transacciones, sino para analizarlas. Por ejemplo:
# 1. Una base transaccional guarda la venta de un producto en tiempo real
# 2. Luego, esa venta se replica al data warehouse para incluirla en un reporte de facturación o un análisis de rentabilidad

# %% [markdown]
# ## Qué es ELT y cómo se diferencia?

# %% [markdown]
# ELT invierte el orden: primero se extrae, luego se carga, y después se transforma directamente dentro del data warehouse. Esto es posible cuando el sistema de destino (ej. BigQuery, Snowflake) es lo suficientemente potente como para transformar datos internamente.

# %% [markdown]
# ## Cuándo usar ETL y cuándo usar ELT?

# %% [markdown]
# **ETL**:
# - Si se necesita preprocesar datos sensibles antes de almacenarlos
# - Si los sistemas destino son limitados o no soportan cargas crudas
# - Si ya se cuenta con infraestructura tradicional o herramientas ETL legacy
#
# **ELT**:
# - Si se usan herramientas cloud modernas (Snowflake, Redshift, BigQuery)
# - Si se requiere trazabilidad y versionado de transformaciones en SQL
# - Si los datos pueden ser cargados en crudo sin riesgos
#
# **Considerar que**:
# - Tanto ETL como ELT son fundamentales en ingeniería de datos
# - No son excluyentes, ya que muchas arquitecturas modernas combinan ambos enfoques
# - Lo importante no es la herramienta, sino entender el flujo de valor del dato: traerlo, hacerlo útil y disponibilizarlo

# %% [markdown]
# # Ejercicios

# %% [markdown]
# ## 1. Leer las ventas del dataset online_retail, inspeccionar los datos, limpiarlos y guardarlos como otro csv

# %%
import pandas as pd
import numpy as np

# Leer el archivo CSV con codificación apropiada

retail_df = pd.read_csv("datos_a_levantar/online_retail.csv", encoding="ISO-8859-1")
retail_df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# 0        12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1        12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2        12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3        12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4        12/1/2010 8:26       3.39     17850.0  United Kingdom
# ...                 ...        ...         ...             ...
# 541904  12/9/2011 12:50       0.85     12680.0          France
# 541905  12/9/2011 12:50       2.10     12680.0          France
# 541906  12/9/2011 12:50       4.15     12680.0          France
# 541907  12/9/2011 12:50       4.15     12680.0          France
# 541908  12/9/2011 12:50       4.95     12680.0          France
#
# [541909 rows x 8 columns]

# %% [markdown]
# Primeras filas del dataset:

# %%
retail_df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
retail_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 8 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   InvoiceNo    541909 non-null  object
#  1   StockCode    541909 non-null  object
#  2   Description  540455 non-null  object
#  3   Quantity     541909 non-null  int64
#  4   InvoiceDate  541909 non-null  object
#  5   UnitPrice    541909 non-null  float64
#  6   CustomerID   406829 non-null  float64
#  7   Country      541909 non-null  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 33.1+ MB

# %%
# Eliminar filas completamente duplicadas

retail_df = retail_df = retail_df.drop_duplicates()
retail_df.shape
# Out:
# (536641, 8)

# %%
# Eliminar filas duplicadas según un subset de columnas

retail_df = retail_df.drop_duplicates(subset=["InvoiceNo", "StockCode"])
retail_df.shape
# Out:
# (531225, 8)

# %%
# Eliminar filas con nulos en columnas clave

retail_df = retail_df.dropna(subset=["InvoiceNo", "StockCode", "Quantity", "UnitPrice"])
retail_df.shape
# Out:
# (531225, 8)

# %%
# Filtrar para obtener sólo cantidades y precios mayores a 0

retail_df = retail_df[(retail_df["Quantity"] > 0) & (retail_df["UnitPrice"] > 0)]
retail_df.shape
# Out:
# (519582, 8)

# %%
# Convertir InvoiceDate a datetime

retail_df["InvoiceDate"] = pd.to_datetime(retail_df["InvoiceDate"])
retail_df.head(5)
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
# Limpiar texto: quitar espacios

retail_df["StockCode"] = retail_df["StockCode"].str.strip()
retail_df["Description"] = retail_df["Description"].str.strip()

retail_df.head(5)
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
# Reemplazar descripciones que contienen "?" por vacío

retail_df["Description"] = retail_df["Description"].apply(lambda x: np.nan if "?" in x else x)

retail_df.head(5)
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
# Eliminar facturas de devolución (que empiezan con 'C')

retail_df = retail_df[~retail_df["InvoiceNo"].astype(str).str.startswith('C')]
retail_df.head(5)
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
# Calcular campo TotalPrice

retail_df["TotalPrice"] = retail_df["Quantity"] * retail_df["UnitPrice"]
retail_df.head(5)
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country  TotalPrice
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom       15.30
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom       20.34
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom       22.00
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom       20.34
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom       20.34

# %%
retail_df.shape
# Out:
# (519582, 9)

# %%
# Limpiar CustomerID

#retail_df = retail_df.dropna(subset=["CustomerID"])
retail_df["CustomerID"] = retail_df["CustomerID"].fillna(-1)

retail_df["CustomerID"] = retail_df["CustomerID"].astype(int)
retail_df.head(5)
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country  TotalPrice
# 0 2010-12-01 08:26:00       2.55       17850  United Kingdom       15.30
# 1 2010-12-01 08:26:00       3.39       17850  United Kingdom       20.34
# 2 2010-12-01 08:26:00       2.75       17850  United Kingdom       22.00
# 3 2010-12-01 08:26:00       3.39       17850  United Kingdom       20.34
# 4 2010-12-01 08:26:00       3.39       17850  United Kingdom       20.34

# %%
retail_df.shape
# Out:
# (519582, 9)

# %%
# Resetear índice

retail_df = retail_df.reset_index(drop=True)
retail_df.head(5)
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country  TotalPrice
# 0 2010-12-01 08:26:00       2.55       17850  United Kingdom       15.30
# 1 2010-12-01 08:26:00       3.39       17850  United Kingdom       20.34
# 2 2010-12-01 08:26:00       2.75       17850  United Kingdom       22.00
# 3 2010-12-01 08:26:00       3.39       17850  United Kingdom       20.34
# 4 2010-12-01 08:26:00       3.39       17850  United Kingdom       20.34

# %%
retail_df.to_csv("resultados/online_retail_clean.csv")

# %% [markdown]
# ## 2. Leer un xlsx, unpivotearlo y pivotearlo, y guardar los resultados

# %%
"""
import pandas as pd
import numpy as np

np.random.seed(42)  # Para reproducibilidad

departamentos = [
    ("Finanzas", "Contabilidad"),
    ("IT", "Infraestructura"),
    ("IT", "Desarrollo"),
    ("Marketing", "Digital"),
    ("Marketing", "Eventos")
]

meses = [
    "Enero", "Febrero", "Marzo", "Abril", "Mayo", "Junio",
    "Julio", "Agosto", "Septiembre", "Octubre", "Noviembre", "Diciembre"
]

# Generar datos con dispersión
rows = []
for dept, sub in departamentos:
    base_headcount = np.random.randint(2, 7)
    for mes in meses:
        # Headcount varía un poco mes a mes
        headcount = base_headcount + np.random.randint(-1, 2)
        headcount = max(1, headcount)  # mínimo 1
        # Presupuesto basado en headcount con dispersión adicional
        presupuesto = headcount * np.random.randint(4000, 7000)
        rows.append({
            "Departamento": dept,
            "Subdepartamento": sub,
            f"{mes} Headcount": headcount,
            f"{mes} Presupuesto": presupuesto
        })

# Combinar columnas mensuales por tipo
from collections import defaultdict
rows_agrupados = defaultdict(dict)
for row in rows:
    key = (row["Departamento"], row["Subdepartamento"])
    for k, v in row.items():
        if k not in ("Departamento", "Subdepartamento"):
            rows_agrupados[key][k] = v
    rows_agrupados[key]["Departamento"] = key[0]
    rows_agrupados[key]["Subdepartamento"] = key[1]

# Convertir a DataFrame
presupuesto_df = pd.DataFrame(rows_agrupados.values())


# Definir orden de meses y métricas
meses = [
    "Enero", "Febrero", "Marzo", "Abril", "Mayo", "Junio",
    "Julio", "Agosto", "Septiembre", "Octubre", "Noviembre", "Diciembre"
]
metricas = ["Headcount", "Presupuesto"]

# Generar lista ordenada de columnas
columnas_ordenadas = ["Departamento", "Subdepartamento"]
for mes in meses:
    for m in metricas:
        columnas_ordenadas.append(f"{mes} {m}")

# Reordenar columnas
presupuesto_df = presupuesto_df[columnas_ordenadas]


# Guardar el archivo con datos más realistas
presupuesto_df.to_excel("datos_a_levantar/presupuesto_2024.xlsx", index=False)

print("Archivo generado con dispersión realista.")
"""
# Out:
# '\nimport pandas as pd\nimport numpy as np\n\nnp.random.seed(42)  # Para reproducibilidad\n\ndepartamentos = [\n    ("Finanzas", "Contabilidad"),\n    ("IT", "Infraestructura"),\n    ("IT", "Desarrollo"),\n    ("Marketing", "Digital"),\n    ("Marketing", "Eventos")\n]\n\nmeses = [\n    "Enero", "Febrero", "Marzo", "Abril", "Mayo", "Junio",\n    "Julio", "Agosto", "Septiembre", "Octubre", "Noviembre", "Diciembre"\n]\n\n# Generar datos con dispersión\nrows = []\nfor dept, sub in departamentos:\n    base_headcount = np.random.randint(2, 7)\n    for mes in meses:\n        # Headcount varía un poco mes a mes\n        headcount = base_headcount + np.random.randint(-1, 2)\n        headcount = max(1, headcount)  # mínimo 1\n        # Presupuesto basado en headcount con dispersión adicional\n        presupuesto = headcount * np.random.randint(4000, 7000)\n        rows.append({\n            "Departamento": dept,\n            "Subdepartamento": sub,\n            f"{mes} Headcount": headcount,\n            f"{mes} Presupuesto": presupuesto\n        })\n\n# Combinar columnas mensuales por tipo\nfrom collections import defaultdict\nrows_agrupados = defaultdict(dict)\nfor row in rows:\n    key = (row["Departamento"], row["Subdepartamento"])\n    for k, v in row.items():\n        if k not in ("Departamento", "Subdepartamento"):\n            rows_agrupados[key][k] = v\n    rows_agrupados[key]["Departamento"] = key[0]\n    rows_agrupados[key]["Subdepartamento"] = key[1]\n\n# Convertir a DataFrame\npresupuesto_df = pd.DataFrame(rows_agrupados.values())\n\n\n# Definir orden de meses y métricas\nmeses = [\n    "Enero", "Febrero", "Marzo", "Abril", "Mayo", "Junio",\n    "Julio", "Agosto", "Septiembre", "Octubre", "Noviembre", "Diciembre"\n]\nmetricas = ["Headcount", "Presupuesto"]\n\n# Generar lista ordenada de columnas\ncolumnas_ordenadas = ["Departamento", "Subdepartamento"]\nfor mes in meses:\n    for m in metricas:\n        columnas_ordenadas.append(f"{mes} {m}")\n\n# Reordenar columnas\npresupuesto_df = presupuesto_df[columnas_ordenadas]\n\n\n# Guardar el archivo con datos más realistas\npresupuesto_df.to_excel("datos_a_levantar/presupuesto_2024.xlsx", index=False)\n\nprint("Archivo generado con dispersión realista.")\n'

# %%
# 1. Leer el archivo original
presupuesto_df = pd.read_excel("datos_a_levantar/presupuesto_2024.xlsx", engine="openpyxl")
presupuesto_df.head(5)
# Out:
#   Departamento  Subdepartamento  Enero Headcount  Enero Presupuesto  \
# 0     Finanzas     Contabilidad                4              21176
# 1           IT  Infraestructura                5              20105
# 2           IT       Desarrollo                4              25452
# 3    Marketing          Digital                3              16737
# 4    Marketing          Eventos                5              32840
#
#    Febrero Headcount  Febrero Presupuesto  Marzo Headcount  Marzo Presupuesto  \
# 0                  6                30570                4              22552
# 1                  4                18988                4              17896
# 2                  5                21205                5              34120
# 3                  3                12603                3              14985
# 4                  5                30135                7              36134
#
#    Abril Headcount  Abril Presupuesto  ...  Agosto Headcount  \
# 0                5              22330  ...                 6
# 1                6              39348  ...                 5
# 2                5              33060  ...                 6
# 3                3              14445  ...                 2
# 4                7              46480  ...                 6
#
#    Agosto Presupuesto  Septiembre Headcount  Septiembre Presupuesto  \
# 0               34110                     4                   19076
# 1               22810                     6                   31602
# 2               24204                     5                   29775
# 3               13534                     2                    8674
# 4               36528                     7                   29400
#
#    Octubre Headcount  Octubre Presupuesto  Noviembre Headcount  \
# 0                  5                34265                    5
# 1                  4                18584                    4
# 2                  5                25105                    5
# 3                  4                20304                    3
# 4                  6                27012                    7
#
#    Noviembre Presupuesto  Diciembre Headcount  Diciembre Presupuesto
# 0                  26075                    4                  20736
# 1                  27552                    6                  31782
# 2                  33065                    5                  27500
# 3                  18792                    2                  10360
# 4                  40257                    5                  30730
#
# [5 rows x 26 columns]

# %%
# Unpivot

presupuesto_unpivot = presupuesto_df.melt(
    id_vars=["Departamento", "Subdepartamento"],
    var_name="Mes_Tipo",
    value_name="Valor"
)

presupuesto_unpivot = presupuesto_unpivot.sort_values(by=["Departamento", "Subdepartamento"], ascending=True)
presupuesto_unpivot.head(20)
# Out:
#    Departamento Subdepartamento                Mes_Tipo  Valor
# 0      Finanzas    Contabilidad         Enero Headcount      4
# 5      Finanzas    Contabilidad       Enero Presupuesto  21176
# 10     Finanzas    Contabilidad       Febrero Headcount      6
# 15     Finanzas    Contabilidad     Febrero Presupuesto  30570
# 20     Finanzas    Contabilidad         Marzo Headcount      4
# 25     Finanzas    Contabilidad       Marzo Presupuesto  22552
# 30     Finanzas    Contabilidad         Abril Headcount      5
# 35     Finanzas    Contabilidad       Abril Presupuesto  22330
# 40     Finanzas    Contabilidad          Mayo Headcount      6
# 45     Finanzas    Contabilidad        Mayo Presupuesto  25980
# 50     Finanzas    Contabilidad         Junio Headcount      6
# 55     Finanzas    Contabilidad       Junio Presupuesto  36810
# 60     Finanzas    Contabilidad         Julio Headcount      4
# 65     Finanzas    Contabilidad       Julio Presupuesto  27676
# 70     Finanzas    Contabilidad        Agosto Headcount      6
# 75     Finanzas    Contabilidad      Agosto Presupuesto  34110
# 80     Finanzas    Contabilidad    Septiembre Headcount      4
# 85     Finanzas    Contabilidad  Septiembre Presupuesto  19076
# 90     Finanzas    Contabilidad       Octubre Headcount      5
# 95     Finanzas    Contabilidad     Octubre Presupuesto  34265

# %%
# Separar mes y tipo a través de usar regular expressions (RegEx)

presupuesto_unpivot[["Mes", "Tipo"]] = presupuesto_unpivot["Mes_Tipo"].str.extract(r"(\w+)\s+(Headcount|Presupuesto)")
presupuesto_unpivot.head(10)
# Out:
#    Departamento Subdepartamento             Mes_Tipo  Valor      Mes  \
# 0      Finanzas    Contabilidad      Enero Headcount      4    Enero
# 5      Finanzas    Contabilidad    Enero Presupuesto  21176    Enero
# 10     Finanzas    Contabilidad    Febrero Headcount      6  Febrero
# 15     Finanzas    Contabilidad  Febrero Presupuesto  30570  Febrero
# 20     Finanzas    Contabilidad      Marzo Headcount      4    Marzo
# 25     Finanzas    Contabilidad    Marzo Presupuesto  22552    Marzo
# 30     Finanzas    Contabilidad      Abril Headcount      5    Abril
# 35     Finanzas    Contabilidad    Abril Presupuesto  22330    Abril
# 40     Finanzas    Contabilidad       Mayo Headcount      6     Mayo
# 45     Finanzas    Contabilidad     Mayo Presupuesto  25980     Mayo
#
#            Tipo
# 0     Headcount
# 5   Presupuesto
# 10    Headcount
# 15  Presupuesto
# 20    Headcount
# 25  Presupuesto
# 30    Headcount
# 35  Presupuesto
# 40    Headcount
# 45  Presupuesto

# %% [markdown]
# (\w+)         → Captura una o más letras/dígitos/subguiones → corresponde al mes
#
# \s+           → Uno o más espacios (separador entre palabras)
#
# (Headcount|Presupuesto) → Captura exactamente una de esas dos palabras

# %% [markdown]
# Ahora, no queremos que cada mes aparezca dos veces para cada subdepartamento. Por lo cual, queremos pivotear la data para que para un mes y un subdepartamento dado, haya una columna de headcount y otra de presupuesto.
#
# Esto se logra pivoteando la data, que lo hacemos a continuación.

# %%
# Pivot final

presupuesto_transformado = presupuesto_unpivot.pivot_table(
    index=["Departamento", "Subdepartamento", "Mes"],
    columns="Tipo",
    values="Valor",
    aggfunc="sum"
).reset_index()

presupuesto_transformado.head(15)
# Out:
# Tipo Departamento Subdepartamento         Mes  Headcount  Presupuesto
# 0        Finanzas    Contabilidad       Abril          5        22330
# 1        Finanzas    Contabilidad      Agosto          6        34110
# 2        Finanzas    Contabilidad   Diciembre          4        20736
# 3        Finanzas    Contabilidad       Enero          4        21176
# 4        Finanzas    Contabilidad     Febrero          6        30570
# 5        Finanzas    Contabilidad       Julio          4        27676
# 6        Finanzas    Contabilidad       Junio          6        36810
# 7        Finanzas    Contabilidad       Marzo          4        22552
# 8        Finanzas    Contabilidad        Mayo          6        25980
# 9        Finanzas    Contabilidad   Noviembre          5        26075
# 10       Finanzas    Contabilidad     Octubre          5        34265
# 11       Finanzas    Contabilidad  Septiembre          4        19076
# 12             IT      Desarrollo       Abril          5        33060
# 13             IT      Desarrollo      Agosto          6        24204
# 14             IT      Desarrollo   Diciembre          5        27500

# %% [markdown]
# Los meses no están ordenados. Si bien no es indispensable, la data sería más fácil de leer si los meses estuvieran ordenados.
#
# Pero hay un desafío. Pandas no entiende la cronología de estos meses, y los interpreta como strings (objects en Pandas). Por lo tanto, si ordenamos por mes, estaríamos ordenado alfabéticamente, y eso no es lo que querríamos hacer.
#
# Para solucionar esto, vamos a definir a la columna mes como CATEGORICAL.

# %%
orden_meses = [
    "Enero", "Febrero", "Marzo", "Abril", "Mayo", "Junio",
    "Julio", "Agosto", "Septiembre", "Octubre", "Noviembre", "Diciembre"
]

# %%
presupuesto_transformado["Mes"] = pd.Categorical(
    presupuesto_transformado["Mes"],
    categories=orden_meses,
    ordered=True
)

# %%
presupuesto_transformado = presupuesto_transformado.sort_values(
    by=["Departamento", "Subdepartamento", "Mes"]
).reset_index(drop=True)

presupuesto_transformado.head(15)
# Out:
# Tipo Departamento Subdepartamento         Mes  Headcount  Presupuesto
# 0        Finanzas    Contabilidad       Enero          4        21176
# 1        Finanzas    Contabilidad     Febrero          6        30570
# 2        Finanzas    Contabilidad       Marzo          4        22552
# 3        Finanzas    Contabilidad       Abril          5        22330
# 4        Finanzas    Contabilidad        Mayo          6        25980
# 5        Finanzas    Contabilidad       Junio          6        36810
# 6        Finanzas    Contabilidad       Julio          4        27676
# 7        Finanzas    Contabilidad      Agosto          6        34110
# 8        Finanzas    Contabilidad  Septiembre          4        19076
# 9        Finanzas    Contabilidad     Octubre          5        34265
# 10       Finanzas    Contabilidad   Noviembre          5        26075
# 11       Finanzas    Contabilidad   Diciembre          4        20736
# 12             IT      Desarrollo       Enero          4        25452
# 13             IT      Desarrollo     Febrero          5        21205
# 14             IT      Desarrollo       Marzo          5        34120

# %% [markdown]
# Convertimos la columna "Mes" de tipo object (texto común) a un tipo especial: Categorical.
#
# Un Categorical en pandas es una columna que:
# - Tiene un número limitado de valores posibles (categories)
# - Puede tener un orden explícito si se lo indica (ordered=True)

# %%
# Finalmente, guardamos el archivo

presupuesto_transformado.to_excel("resultados/presupuesto_2024_transformado.xlsx", index=False)

# %% [markdown]
# ## 3. Obtener datos usando una API, limpiarlos, y guardar el resultado como un csv

# %%
import requests

# %%
url = "https://api.bcra.gob.ar/estadisticascambiarias/v1.0/Cotizaciones"
params = {"fecha": "2025-04-16"}

response = requests.get(url, params=params, verify=False)

if response.status_code == 200:
    print(response.json())
else:
    print(f"Error: {response.status_code}")
# Out:
# c:\Users\Estefano\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.bcra.gob.ar'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# {'status': 200, 'results': {'fecha': '2025-04-16', 'detalle': [{'codigoMoneda': 'ARS', 'descripcion': 'PESO', 'tipoPase': 0.000881, 'tipoCotizacion': 0.0}, {'codigoMoneda': 'AUD', 'descripcion': 'DOLAR AUSTRALIA', 'tipoPase': 0.6362, 'tipoCotizacion': 722.087}, {'codigoMoneda': 'AWG', 'descripcion': 'FLORIN (ANTILLAS HOLANDESAS)', 'tipoPase': 0.558659, 'tipoCotizacion': 634.078212}, {'codigoMoneda': 'BOB', 'descripcion': 'BOLIVIANOS', 'tipoPase': 0.145159, 'tipoCotizacion': 164.755407}, {'codigoMoneda': 'BRL', 'descripcion': 'REAL', 'tipoPase': 0.170413, 'tipoCotizacion': 193.418653}, {'codigoMoneda': 'CAD', 'descripcion': 'DOLAR CANADIEN.', 'tipoPase': 0.719683, 'tipoCotizacion': 816.84059}, {'codigoMoneda': 'CHF', 'descripcion': 'FRANCO SUIZO', 'tipoPase': 1.226392, 'tipoCotizacion': 1391.954869}, {'codigoMoneda': 'CLP', 'descripcion': 'PESO CHILENO', 'tipoPase': 0.001031, 'tipoCotizacion': 1.169633}, {'codigoMoneda': 'CNH', 'descripcion': 'YUAN CNH RENMINBI OFF SHORE', 'tipoPase': 0.136919, 'tipoCotizacion': 155.402815}, {'codigoMoneda': 'CNY', 'descripcion': 'YUAN CNY RENMINBI', 'tipoPase': 0.136996, 'tipoCotizacion': 155.490102}, {'codigoMoneda': 'COP', 'descripcion': 'COLOMBIANOS', 'tipoPase': 0.000232, 'tipoCotizacion': 0.2636}, {'codigoMoneda': 'CZK', 'descripcion': 'CORONAS CHECAS', 'tipoPase': 0.045475, 'tipoCotizacion': 51.61437}, {'codigoMoneda': 'DKK', 'descripcion': 'CORONAS DANESAS', 'tipoPase': 0.152325, 'tipoCotizacion': 172.889153}, {'codigoMoneda': 'EUR', 'descripcion': 'EURO', 'tipoPase': 1.1375, 'tipoCotizacion': 1291.0625}, {'codigoMoneda': 'GBP', 'descripcion': 'LIBRA ESTERLINA', 'tipoPase': 1.3218, 'tipoCotizacion': 1500.243}, {'codigoMoneda': 'HKD', 'descripcion': 'DOLAR HONG KONG', 'tipoPase': 0.128864, 'tipoCotizacion': 146.261002}, {'codigoMoneda': 'ILS', 'descripcion': 'LIBRA ISRAELI', 'tipoPase': 0.271098, 'tipoCotizacion': 307.696478}, {'codigoMoneda': 'INR', 'descripcion': 'RUPIA (INDIA)', 'tipoPase': 0.011671, 'tipoCotizacion': 13.246192}, {'codigoMoneda': 'JPY', 'descripcion': 'YENS', 'tipoPase': 0.007023, 'tipoCotizacion': 7.971065}, {'codigoMoneda': 'MXP', 'descripcion': 'PESO MEXICANO', 'tipoPase': 0.050005, 'tipoCotizacion': 56.755676}, {'codigoMoneda': 'NIO', 'descripcion': 'CORDOBA NICARAGUENSE', 'tipoPase': 0.02717, 'tipoCotizacion': 30.837447}, {'codigoMoneda': 'NOK', 'descripcion': 'CORONAS NORUEGA', 'tipoPase': 0.094387, 'tipoCotizacion': 107.129036}, {'codigoMoneda': 'NZD', 'descripcion': 'DOLAR NEOZELANDES', 'tipoPase': 0.5914, 'tipoCotizacion': 671.239}, {'codigoMoneda': 'PEN', 'descripcion': 'SOLES', 'tipoPase': 0.267917, 'tipoCotizacion': 304.085733}, {'codigoMoneda': 'PYG', 'descripcion': 'GUARANIES', 'tipoPase': 0.000125, 'tipoCotizacion': 0.141746}, {'codigoMoneda': 'REF', 'descripcion': 'DOLAR REFERENCIA COM 3500', 'tipoPase': 0.0, 'tipoCotizacion': 1172.8333}, {'codigoMoneda': 'RSD', 'descripcion': 'DINAR SERBIA', 'tipoPase': 0.009702, 'tipoCotizacion': 11.011464}, {'codigoMoneda': 'RUB', 'descripcion': 'RUSIA', 'tipoPase': 0.012046, 'tipoCotizacion': 13.672294}, {'codigoMoneda': 'SEK', 'descripcion': 'CORONAS SUECAS', 'tipoPase': 0.102219, 'tipoCotizacion': 116.018767}, {'codigoMoneda': 'SGD', 'descripcion': 'DOLAR DE SINGAPUR', 'tipoPase': 0.762079, 'tipoCotizacion': 864.95961}, {'codigoMoneda': 'TRY', 'descripcion': 'LIRA TURCA', 'tipoPase': 0.02623, 'tipoCotizacion': 29.771195}, {'codigoMoneda': 'USD', 'descripcion': 'DOLAR E.E.U.U.', 'tipoPase': 0.0, 'tipoCotizacion': 1135.0}, {'codigoMoneda': 'UYU', 'descripcion': 'PESO URUGUAYO', 'tipoPase': 0.023643, 'tipoCotizacion': 26.835323}, {'codigoMoneda': 'VEB', 'descripcion': 'BOLIVARES', 'tipoPase': 0.01255266, 'tipoCotizacion': 14.24726729}, {'codigoMoneda': 'VND', 'descripcion': 'DONG VIETNAM (C/1.000 UNIDADES)', 'tipoPase': 0.038694, 'tipoCotizacion': 43.91735}, {'codigoMoneda': 'XAG', 'descripcion': 'PLATA - ONZA TROY', 'tipoPase': 32.8033, 'tipoCotizacion': 0.0}, {'codigoMoneda': 'XAU', 'descripcion': 'ORO FINO (1 ONZ ...

# %%
response
# Out:
# <Response [200]>

# %%
type(response)
# Out:
# requests.models.Response

# %%
type(response.json())
# Out:
# dict

# %%
response.json().keys()
# Out:
# dict_keys(['status', 'results'])

# %%
response.json()['status']
# Out:
# 200

# %%
response.json()['results']
# Out:
# {'fecha': '2025-04-16',
#  'detalle': [{'codigoMoneda': 'ARS',
#    'descripcion': 'PESO',
#    'tipoPase': 0.000881,
#    'tipoCotizacion': 0.0},
#   {'codigoMoneda': 'AUD',
#    'descripcion': 'DOLAR AUSTRALIA',
#    'tipoPase': 0.6362,
#    'tipoCotizacion': 722.087},
#   {'codigoMoneda': 'AWG',
#    'descripcion': 'FLORIN (ANTILLAS HOLANDESAS)',
#    'tipoPase': 0.558659,
#    'tipoCotizacion': 634.078212},
#   {'codigoMoneda': 'BOB',
#    'descripcion': 'BOLIVIANOS',
#    'tipoPase': 0.145159,
#    'tipoCotizacion': 164.755407},
#   {'codigoMoneda': 'BRL',
#    'descripcion': 'REAL',
#    'tipoPase': 0.170413,
#    'tipoCotizacion': 193.418653},
#   {'codigoMoneda': 'CAD',
#    'descripcion': 'DOLAR CANADIEN.',
#    'tipoPase': 0.719683,
#    'tipoCotizacion': 816.84059},
#   {'codigoMoneda': 'CHF',
#    'descripcion': 'FRANCO SUIZO',
#    'tipoPase': 1.226392,
#    'tipoCotizacion': 1391.954869},
#   {'codigoMoneda': 'CLP',
#    'descripcion': 'PESO CHILENO',
#    'tipoPase': 0.001031,
#    'tipoCotizacion': 1.169633},
#   {'codigoMoneda': 'CNH',
#    'descripcion': 'YUAN CNH RENMINBI OFF SHORE',
#    'tipoPase': 0.136919,
#    'tipoCotizacion': 155.402815},
#   {'codigoMoneda': 'CNY',
#    'descripcion': 'YUAN CNY RENMINBI',
#    'tipoPase': 0.136996,
#    'tipoCotizacion': 155.490102},
#   {'codigoMoneda': 'COP',
#    'descripcion': 'COLOMBIANOS',
#    'tipoPase': 0.000232,
#    'tipoCotizacion': 0.2636},
#   {'codigoMoneda': 'CZK',
#    'descripcion': 'CORONAS CHECAS',
#    'tipoPase': 0.045475,
#    'tipoCotizacion': 51.61437},
#   {'codigoMoneda': 'DKK',
#    'descripcion': 'CORONAS DANESAS',
#    'tipoPase': 0.152325,
#    'tipoCotizacion': 172.889153},
#   {'codigoMoneda': 'EUR',
#    'descripcion': 'EURO',
#    'tipoPase': 1.1375,
#    'tipoCotizacion': 1291.0625},
#   {'codigoMoneda': 'GBP',
#    'descripcion': 'LIBRA ESTERLINA',
#    'tipoPase': 1.3218,
#    'tipoCotizacion': 1500.243},
#   {'codigoMoneda': 'HKD',
#    'descripcion': 'DOLAR HONG KONG',
#    'tipoPase': 0.128864,
#    'tipoCotizacion': 146.261002},
#   {'codigoMoneda': 'ILS',
#    'descripcion': 'LIBRA ISRAELI',
#    'tipoPase': 0.271098,
#    'tipoCotizacion': 307.696478},
#   {'codigoMoneda': 'INR',
#    'descripcion': 'RUPIA (INDIA)',
#    'tipoPase': 0.011671,
#    'tipoCotizacion': 13.246192},
#   {'codigoMoneda': 'JPY',
#    'descripcion': 'YENS',
#    'tipoPase': 0.007023,
#    'tipoCotizacion': 7.971065},
#   {'codigoMoneda': 'MXP',
#    'descripcion': 'PESO MEXICANO',
#    'tipoPase': 0.050005,
#    'tipoCotizacion': 56.755676},
#   {'codigoMoneda': 'NIO',
#    'descripcion': 'CORDOBA NICARAGUENSE',
#    'tipoPase': 0.02717,
#    'tipoCotizacion': 30.837447},
#   {'codigoMoneda': 'NOK',
#    'descripcion': 'CORONAS NORUEGA',
#    'tipoPase': 0.094387,
#    'tipoCotizacion': 107.129036},
#   {'codigoMoneda': 'NZD',
#    'descripcion': 'DOLAR NEOZELANDES',
#    'tipoPase': 0.5914,
#    'tipoCotizacion': 671.239},
#   {'codigoMoneda': 'PEN',
#    'descripcion': 'SOLES',
#    'tipoPase': 0.267917,
#    'tipoCotizacion': 304.085733},
#   {'codigoMoneda': 'PYG',
#    'descripcion': 'GUARANIES',
#    'tipoPase': 0.000125,
#    'tipoCotizacion': 0.141746},
#   {'codigoMoneda': 'REF',
#    'descripcion': 'DOLAR REFERENCIA COM 3500',
#    'tipoPase': 0.0,
#    'tipoCotizacion': 1172.8333},
#   {'codigoMoneda': 'RSD',
#    'descripcion': 'DINAR SERBIA',
#    'tipoPase': 0.009702,
#    'tipoCotizacion': 11.011464},
#   {'codigoMoneda': 'RUB',
#    'descripcion': 'RUSIA',
#    'tipoPase': 0.012046,
#    'tipoCotizacion': 13.672294},
#   {'codigoMoneda': 'SEK',
#    'descripcion': 'CORONAS SUECAS',
#    'tipoPase': 0.102219,
#    'tipoCotizacion': 116.018767},
#   {'codigoMoneda': 'SGD',
#    'descripcion': 'DOLAR DE SINGAPUR',
#    'tipoPase': 0.762079,
#    'tipoCotizacion': 864.95961},
#   {'codigoMoneda': 'TRY',
#    'descripcion': 'LIRA TURCA',
#    'tipoPase': 0.02623,
#    'tipoCotizacion': 29.771195},
#   {'codigoMoneda': 'USD',
#    'descripcion': 'DOLAR E.E.U.U.',
#    'tipoPase': 0.0,
#    'tipoCotizacion': 1135.0},
#   {'codigoMoneda': 'UYU',
#    'descripcion': 'PESO URUGUAYO',
#    'tipoPase': 0.023643,
#    'tipoCotizacion': 26.835323},
#   {'codigoMoneda': 'VEB',
#    'descripcion': 'BOLIVARES',
#    'tipoPase': 0.01255266,
#    'tipoCotizacion': 14.24726729},
#   {'codigoMoneda': 'VND',
#    'descripcion': 'DONG VIETNAM (C/1.000 UNIDADES)',
#    'tipoPase': 0.038694,
#    'tipoCotizacion': 43.91735},
#   {'codigoMoneda': 'XAG',
#    'descripcion': 'PLATA - ONZA TROY',
#    'tipoPase': 32.8033,
#    'tipoCotizacion': 0.0},
#   {'codigoMoneda': 'XAU',
#    'descripcion': 'ORO FINO (1 ONZA)',
#    'tipoPase': 3327.38,
#    'tipoCotizacion': 0.0},
#   {'codigoMoneda': 'XDR',
#    'descripcion': 'DEG',
#    'tipoPase': 1.35473,
#    'tipoCotizacion': 1537.61855},
#   {'codigoMoneda': 'ZAR',
#    'descripcion': 'RAND SUD',
#    'tipoPase': 0.053057,
#    'tipoCotizacion': 60.219869}]}

# %%
response.json()['results']['detalle']
# Out:
# [{'codigoMoneda': 'ARS',
#   'descripcion': 'PESO',
#   'tipoPase': 0.000881,
#   'tipoCotizacion': 0.0},
#  {'codigoMoneda': 'AUD',
#   'descripcion': 'DOLAR AUSTRALIA',
#   'tipoPase': 0.6362,
#   'tipoCotizacion': 722.087},
#  {'codigoMoneda': 'AWG',
#   'descripcion': 'FLORIN (ANTILLAS HOLANDESAS)',
#   'tipoPase': 0.558659,
#   'tipoCotizacion': 634.078212},
#  {'codigoMoneda': 'BOB',
#   'descripcion': 'BOLIVIANOS',
#   'tipoPase': 0.145159,
#   'tipoCotizacion': 164.755407},
#  {'codigoMoneda': 'BRL',
#   'descripcion': 'REAL',
#   'tipoPase': 0.170413,
#   'tipoCotizacion': 193.418653},
#  {'codigoMoneda': 'CAD',
#   'descripcion': 'DOLAR CANADIEN.',
#   'tipoPase': 0.719683,
#   'tipoCotizacion': 816.84059},
#  {'codigoMoneda': 'CHF',
#   'descripcion': 'FRANCO SUIZO',
#   'tipoPase': 1.226392,
#   'tipoCotizacion': 1391.954869},
#  {'codigoMoneda': 'CLP',
#   'descripcion': 'PESO CHILENO',
#   'tipoPase': 0.001031,
#   'tipoCotizacion': 1.169633},
#  {'codigoMoneda': 'CNH',
#   'descripcion': 'YUAN CNH RENMINBI OFF SHORE',
#   'tipoPase': 0.136919,
#   'tipoCotizacion': 155.402815},
#  {'codigoMoneda': 'CNY',
#   'descripcion': 'YUAN CNY RENMINBI',
#   'tipoPase': 0.136996,
#   'tipoCotizacion': 155.490102},
#  {'codigoMoneda': 'COP',
#   'descripcion': 'COLOMBIANOS',
#   'tipoPase': 0.000232,
#   'tipoCotizacion': 0.2636},
#  {'codigoMoneda': 'CZK',
#   'descripcion': 'CORONAS CHECAS',
#   'tipoPase': 0.045475,
#   'tipoCotizacion': 51.61437},
#  {'codigoMoneda': 'DKK',
#   'descripcion': 'CORONAS DANESAS',
#   'tipoPase': 0.152325,
#   'tipoCotizacion': 172.889153},
#  {'codigoMoneda': 'EUR',
#   'descripcion': 'EURO',
#   'tipoPase': 1.1375,
#   'tipoCotizacion': 1291.0625},
#  {'codigoMoneda': 'GBP',
#   'descripcion': 'LIBRA ESTERLINA',
#   'tipoPase': 1.3218,
#   'tipoCotizacion': 1500.243},
#  {'codigoMoneda': 'HKD',
#   'descripcion': 'DOLAR HONG KONG',
#   'tipoPase': 0.128864,
#   'tipoCotizacion': 146.261002},
#  {'codigoMoneda': 'ILS',
#   'descripcion': 'LIBRA ISRAELI',
#   'tipoPase': 0.271098,
#   'tipoCotizacion': 307.696478},
#  {'codigoMoneda': 'INR',
#   'descripcion': 'RUPIA (INDIA)',
#   'tipoPase': 0.011671,
#   'tipoCotizacion': 13.246192},
#  {'codigoMoneda': 'JPY',
#   'descripcion': 'YENS',
#   'tipoPase': 0.007023,
#   'tipoCotizacion': 7.971065},
#  {'codigoMoneda': 'MXP',
#   'descripcion': 'PESO MEXICANO',
#   'tipoPase': 0.050005,
#   'tipoCotizacion': 56.755676},
#  {'codigoMoneda': 'NIO',
#   'descripcion': 'CORDOBA NICARAGUENSE',
#   'tipoPase': 0.02717,
#   'tipoCotizacion': 30.837447},
#  {'codigoMoneda': 'NOK',
#   'descripcion': 'CORONAS NORUEGA',
#   'tipoPase': 0.094387,
#   'tipoCotizacion': 107.129036},
#  {'codigoMoneda': 'NZD',
#   'descripcion': 'DOLAR NEOZELANDES',
#   'tipoPase': 0.5914,
#   'tipoCotizacion': 671.239},
#  {'codigoMoneda': 'PEN',
#   'descripcion': 'SOLES',
#   'tipoPase': 0.267917,
#   'tipoCotizacion': 304.085733},
#  {'codigoMoneda': 'PYG',
#   'descripcion': 'GUARANIES',
#   'tipoPase': 0.000125,
#   'tipoCotizacion': 0.141746},
#  {'codigoMoneda': 'REF',
#   'descripcion': 'DOLAR REFERENCIA COM 3500',
#   'tipoPase': 0.0,
#   'tipoCotizacion': 1172.8333},
#  {'codigoMoneda': 'RSD',
#   'descripcion': 'DINAR SERBIA',
#   'tipoPase': 0.009702,
#   'tipoCotizacion': 11.011464},
#  {'codigoMoneda': 'RUB',
#   'descripcion': 'RUSIA',
#   'tipoPase': 0.012046,
#   'tipoCotizacion': 13.672294},
#  {'codigoMoneda': 'SEK',
#   'descripcion': 'CORONAS SUECAS',
#   'tipoPase': 0.102219,
#   'tipoCotizacion': 116.018767},
#  {'codigoMoneda': 'SGD',
#   'descripcion': 'DOLAR DE SINGAPUR',
#   'tipoPase': 0.762079,
#   'tipoCotizacion': 864.95961},
#  {'codigoMoneda': 'TRY',
#   'descripcion': 'LIRA TURCA',
#   'tipoPase': 0.02623,
#   'tipoCotizacion': 29.771195},
#  {'codigoMoneda': 'USD',
#   'descripcion': 'DOLAR E.E.U.U.',
#   'tipoPase': 0.0,
#   'tipoCotizacion': 1135.0},
#  {'codigoMoneda': 'UYU',
#   'descripcion': 'PESO URUGUAYO',
#   'tipoPase': 0.023643,
#   'tipoCotizacion': 26.835323},
#  {'codigoMoneda': 'VEB',
#   'descripcion': 'BOLIVARES',
#   'tipoPase': 0.01255266,
#   'tipoCotizacion': 14.24726729},
#  {'codigoMoneda': 'VND',
#   'descripcion': 'DONG VIETNAM (C/1.000 UNIDADES)',
#   'tipoPase': 0.038694,
#   'tipoCotizacion': 43.91735},
#  {'codigoMoneda': 'XAG',
#   'descripcion': 'PLATA - ONZA TROY',
#   'tipoPase': 32.8033,
#   'tipoCotizacion': 0.0},
#  {'codigoMoneda': 'XAU',
#   'descripcion': 'ORO FINO (1 ONZA)',
#   'tipoPase': 3327.38,
#   'tipoCotizacion': 0.0},
#  {'codigoMoneda': 'XDR',
#   'descripcion': 'DEG',
#   'tipoPase': 1.35473,
#   'tipoCotizacion': 1537.61855},
#  {'codigoMoneda': 'ZAR',
#   'descripcion': 'RAND SUD',
#   'tipoPase': 0.053057,
#   'tipoCotizacion': 60.219869}]

# %%
type(response.json()['results']['detalle'])
# Out:
# list

# %%
conv_df = pd.DataFrame(response.json()['results']['detalle'])
conv_df
# Out:
#    codigoMoneda                      descripcion     tipoPase  tipoCotizacion
# 0           ARS                             PESO     0.000881        0.000000
# 1           AUD                  DOLAR AUSTRALIA     0.636200      722.087000
# 2           AWG     FLORIN (ANTILLAS HOLANDESAS)     0.558659      634.078212
# 3           BOB                       BOLIVIANOS     0.145159      164.755407
# 4           BRL                             REAL     0.170413      193.418653
# 5           CAD                  DOLAR CANADIEN.     0.719683      816.840590
# 6           CHF                     FRANCO SUIZO     1.226392     1391.954869
# 7           CLP                     PESO CHILENO     0.001031        1.169633
# 8           CNH      YUAN CNH RENMINBI OFF SHORE     0.136919      155.402815
# 9           CNY                YUAN CNY RENMINBI     0.136996      155.490102
# 10          COP                      COLOMBIANOS     0.000232        0.263600
# 11          CZK                   CORONAS CHECAS     0.045475       51.614370
# 12          DKK                  CORONAS DANESAS     0.152325      172.889153
# 13          EUR                             EURO     1.137500     1291.062500
# 14          GBP                  LIBRA ESTERLINA     1.321800     1500.243000
# 15          HKD                  DOLAR HONG KONG     0.128864      146.261002
# 16          ILS                    LIBRA ISRAELI     0.271098      307.696478
# 17          INR                    RUPIA (INDIA)     0.011671       13.246192
# 18          JPY                             YENS     0.007023        7.971065
# 19          MXP                    PESO MEXICANO     0.050005       56.755676
# 20          NIO             CORDOBA NICARAGUENSE     0.027170       30.837447
# 21          NOK                  CORONAS NORUEGA     0.094387      107.129036
# 22          NZD                DOLAR NEOZELANDES     0.591400      671.239000
# 23          PEN                            SOLES     0.267917      304.085733
# 24          PYG                        GUARANIES     0.000125        0.141746
# 25          REF        DOLAR REFERENCIA COM 3500     0.000000     1172.833300
# 26          RSD                     DINAR SERBIA     0.009702       11.011464
# 27          RUB                            RUSIA     0.012046       13.672294
# 28          SEK                   CORONAS SUECAS     0.102219      116.018767
# 29          SGD                DOLAR DE SINGAPUR     0.762079      864.959610
# 30          TRY                       LIRA TURCA     0.026230       29.771195
# 31          USD                   DOLAR E.E.U.U.     0.000000     1135.000000
# 32          UYU                    PESO URUGUAYO     0.023643       26.835323
# 33          VEB                        BOLIVARES     0.012553       14.247267
# 34          VND  DONG VIETNAM (C/1.000 UNIDADES)     0.038694       43.917350
# 35          XAG                PLATA - ONZA TROY    32.803300        0.000000
# 36          XAU                ORO FINO (1 ONZA)  3327.380000        0.000000
# 37          XDR                              DEG     1.354730     1537.618550
# 38          ZAR                         RAND SUD     0.053057       60.219869

# %%
# Agregamos la fecha que usamos como parámetro en la llamada como una columna más del dataset

conv_df_con_fecha = conv_df.copy(deep=True)
conv_df_con_fecha['fecha'] = params['fecha']
conv_df_con_fecha
# Out:
#    codigoMoneda                      descripcion     tipoPase  tipoCotizacion  \
# 0           ARS                             PESO     0.000881        0.000000
# 1           AUD                  DOLAR AUSTRALIA     0.636200      722.087000
# 2           AWG     FLORIN (ANTILLAS HOLANDESAS)     0.558659      634.078212
# 3           BOB                       BOLIVIANOS     0.145159      164.755407
# 4           BRL                             REAL     0.170413      193.418653
# 5           CAD                  DOLAR CANADIEN.     0.719683      816.840590
# 6           CHF                     FRANCO SUIZO     1.226392     1391.954869
# 7           CLP                     PESO CHILENO     0.001031        1.169633
# 8           CNH      YUAN CNH RENMINBI OFF SHORE     0.136919      155.402815
# 9           CNY                YUAN CNY RENMINBI     0.136996      155.490102
# 10          COP                      COLOMBIANOS     0.000232        0.263600
# 11          CZK                   CORONAS CHECAS     0.045475       51.614370
# 12          DKK                  CORONAS DANESAS     0.152325      172.889153
# 13          EUR                             EURO     1.137500     1291.062500
# 14          GBP                  LIBRA ESTERLINA     1.321800     1500.243000
# 15          HKD                  DOLAR HONG KONG     0.128864      146.261002
# 16          ILS                    LIBRA ISRAELI     0.271098      307.696478
# 17          INR                    RUPIA (INDIA)     0.011671       13.246192
# 18          JPY                             YENS     0.007023        7.971065
# 19          MXP                    PESO MEXICANO     0.050005       56.755676
# 20          NIO             CORDOBA NICARAGUENSE     0.027170       30.837447
# 21          NOK                  CORONAS NORUEGA     0.094387      107.129036
# 22          NZD                DOLAR NEOZELANDES     0.591400      671.239000
# 23          PEN                            SOLES     0.267917      304.085733
# 24          PYG                        GUARANIES     0.000125        0.141746
# 25          REF        DOLAR REFERENCIA COM 3500     0.000000     1172.833300
# 26          RSD                     DINAR SERBIA     0.009702       11.011464
# 27          RUB                            RUSIA     0.012046       13.672294
# 28          SEK                   CORONAS SUECAS     0.102219      116.018767
# 29          SGD                DOLAR DE SINGAPUR     0.762079      864.959610
# 30          TRY                       LIRA TURCA     0.026230       29.771195
# 31          USD                   DOLAR E.E.U.U.     0.000000     1135.000000
# 32          UYU                    PESO URUGUAYO     0.023643       26.835323
# 33          VEB                        BOLIVARES     0.012553       14.247267
# 34          VND  DONG VIETNAM (C/1.000 UNIDADES)     0.038694       43.917350
# 35          XAG                PLATA - ONZA TROY    32.803300        0.000000
# 36          XAU                ORO FINO (1 ONZA)  3327.380000        0.000000
# 37          XDR                              DEG     1.354730     1537.618550
# 38          ZAR                         RAND SUD     0.053057       60.219869
#
#          fecha
# 0   2025-04-16
# 1   2025-04-16
# 2   2025-04-16
# 3   2025-04-16
# 4   2025-04-16
# 5   2025-04-16
# 6   2025-04-16
# 7   2025-04-16
# 8   2025-04-16
# 9   2025-04-16
# 10  2025-04-16
# 11  2025-04-16
# 12  2025-04-16
# 13  2025-04-16
# 14  2025-04-16
# 15  2025-04-16
# 16  2025-04-16
# 17  2025-04-16
# 18  2025-04-16
# 19  2025-04-16
# 20  2025-04-16
# 21  2025-04-16
# 22  2025-04-16
# 23  2025-04-16
# 24  2025-04-16
# 25  2025-04-16
# 26  2025-04-16
# 27  2025-04-16
# 28  2025-04-16
# 29  2025-04-16
# 30  2025-04-16
# 31  2025-04-16
# 32  2025-04-16
# 33  2025-04-16
# 34  2025-04-16
# 35  2025-04-16
# 36  2025-04-16
# 37  2025-04-16
# 38  2025-04-16

# %%
# Ordenamos las columnas para que la fecha correspondiente a estos valores de conversión nos quede al comienzo del dataset

conv_df_con_fecha = conv_df_con_fecha[['fecha', 'codigoMoneda', 'descripcion', 'tipoPase', 'tipoCotizacion']]
conv_df_con_fecha.head(5)
# Out:
#         fecha codigoMoneda                   descripcion  tipoPase  \
# 0  2025-04-16          ARS                          PESO  0.000881
# 1  2025-04-16          AUD               DOLAR AUSTRALIA  0.636200
# 2  2025-04-16          AWG  FLORIN (ANTILLAS HOLANDESAS)  0.558659
# 3  2025-04-16          BOB                    BOLIVIANOS  0.145159
# 4  2025-04-16          BRL                          REAL  0.170413
#
#    tipoCotizacion
# 0        0.000000
# 1      722.087000
# 2      634.078212
# 3      164.755407
# 4      193.418653

# %% [markdown]
# Otra manera de agregar la fecha en la primera columna es utilizando la función insert del DataFrame

# %%
conv_df_con_fecha_insert = conv_df.copy(deep=True)

conv_df_con_fecha_insert.insert(0, 'fecha', params['fecha'])
conv_df_con_fecha_insert
# Out:
#          fecha codigoMoneda                      descripcion     tipoPase  \
# 0   2025-04-16          ARS                             PESO     0.000881
# 1   2025-04-16          AUD                  DOLAR AUSTRALIA     0.636200
# 2   2025-04-16          AWG     FLORIN (ANTILLAS HOLANDESAS)     0.558659
# 3   2025-04-16          BOB                       BOLIVIANOS     0.145159
# 4   2025-04-16          BRL                             REAL     0.170413
# 5   2025-04-16          CAD                  DOLAR CANADIEN.     0.719683
# 6   2025-04-16          CHF                     FRANCO SUIZO     1.226392
# 7   2025-04-16          CLP                     PESO CHILENO     0.001031
# 8   2025-04-16          CNH      YUAN CNH RENMINBI OFF SHORE     0.136919
# 9   2025-04-16          CNY                YUAN CNY RENMINBI     0.136996
# 10  2025-04-16          COP                      COLOMBIANOS     0.000232
# 11  2025-04-16          CZK                   CORONAS CHECAS     0.045475
# 12  2025-04-16          DKK                  CORONAS DANESAS     0.152325
# 13  2025-04-16          EUR                             EURO     1.137500
# 14  2025-04-16          GBP                  LIBRA ESTERLINA     1.321800
# 15  2025-04-16          HKD                  DOLAR HONG KONG     0.128864
# 16  2025-04-16          ILS                    LIBRA ISRAELI     0.271098
# 17  2025-04-16          INR                    RUPIA (INDIA)     0.011671
# 18  2025-04-16          JPY                             YENS     0.007023
# 19  2025-04-16          MXP                    PESO MEXICANO     0.050005
# 20  2025-04-16          NIO             CORDOBA NICARAGUENSE     0.027170
# 21  2025-04-16          NOK                  CORONAS NORUEGA     0.094387
# 22  2025-04-16          NZD                DOLAR NEOZELANDES     0.591400
# 23  2025-04-16          PEN                            SOLES     0.267917
# 24  2025-04-16          PYG                        GUARANIES     0.000125
# 25  2025-04-16          REF        DOLAR REFERENCIA COM 3500     0.000000
# 26  2025-04-16          RSD                     DINAR SERBIA     0.009702
# 27  2025-04-16          RUB                            RUSIA     0.012046
# 28  2025-04-16          SEK                   CORONAS SUECAS     0.102219
# 29  2025-04-16          SGD                DOLAR DE SINGAPUR     0.762079
# 30  2025-04-16          TRY                       LIRA TURCA     0.026230
# 31  2025-04-16          USD                   DOLAR E.E.U.U.     0.000000
# 32  2025-04-16          UYU                    PESO URUGUAYO     0.023643
# 33  2025-04-16          VEB                        BOLIVARES     0.012553
# 34  2025-04-16          VND  DONG VIETNAM (C/1.000 UNIDADES)     0.038694
# 35  2025-04-16          XAG                PLATA - ONZA TROY    32.803300
# 36  2025-04-16          XAU                ORO FINO (1 ONZA)  3327.380000
# 37  2025-04-16          XDR                              DEG     1.354730
# 38  2025-04-16          ZAR                         RAND SUD     0.053057
#
#     tipoCotizacion
# 0         0.000000
# 1       722.087000
# 2       634.078212
# 3       164.755407
# 4       193.418653
# 5       816.840590
# 6      1391.954869
# 7         1.169633
# 8       155.402815
# 9       155.490102
# 10        0.263600
# 11       51.614370
# 12      172.889153
# 13     1291.062500
# 14     1500.243000
# 15      146.261002
# 16      307.696478
# 17       13.246192
# 18        7.971065
# 19       56.755676
# 20       30.837447
# 21      107.129036
# 22      671.239000
# 23      304.085733
# 24        0.141746
# 25     1172.833300
# 26       11.011464
# 27       13.672294
# 28      116.018767
# 29      864.959610
# 30       29.771195
# 31     1135.000000
# 32       26.835323
# 33       14.247267
# 34       43.917350
# 35        0.000000
# 36        0.000000
# 37     1537.618550
# 38       60.219869

# %% [markdown]
# Otra manera de obtener los mismos resultados, de manera más directa pero avanzada, se detalla a continuación:

# %%
conv_df_alt = pd.DataFrame(response.json()['results'])
conv_df_alt
# Out:
#          fecha                                            detalle
# 0   2025-04-16  {'codigoMoneda': 'ARS', 'descripcion': 'PESO',...
# 1   2025-04-16  {'codigoMoneda': 'AUD', 'descripcion': 'DOLAR ...
# 2   2025-04-16  {'codigoMoneda': 'AWG', 'descripcion': 'FLORIN...
# 3   2025-04-16  {'codigoMoneda': 'BOB', 'descripcion': 'BOLIVI...
# 4   2025-04-16  {'codigoMoneda': 'BRL', 'descripcion': 'REAL',...
# 5   2025-04-16  {'codigoMoneda': 'CAD', 'descripcion': 'DOLAR ...
# 6   2025-04-16  {'codigoMoneda': 'CHF', 'descripcion': 'FRANCO...
# 7   2025-04-16  {'codigoMoneda': 'CLP', 'descripcion': 'PESO C...
# 8   2025-04-16  {'codigoMoneda': 'CNH', 'descripcion': 'YUAN C...
# 9   2025-04-16  {'codigoMoneda': 'CNY', 'descripcion': 'YUAN C...
# 10  2025-04-16  {'codigoMoneda': 'COP', 'descripcion': 'COLOMB...
# 11  2025-04-16  {'codigoMoneda': 'CZK', 'descripcion': 'CORONA...
# 12  2025-04-16  {'codigoMoneda': 'DKK', 'descripcion': 'CORONA...
# 13  2025-04-16  {'codigoMoneda': 'EUR', 'descripcion': 'EURO',...
# 14  2025-04-16  {'codigoMoneda': 'GBP', 'descripcion': 'LIBRA ...
# 15  2025-04-16  {'codigoMoneda': 'HKD', 'descripcion': 'DOLAR ...
# 16  2025-04-16  {'codigoMoneda': 'ILS', 'descripcion': 'LIBRA ...
# 17  2025-04-16  {'codigoMoneda': 'INR', 'descripcion': 'RUPIA ...
# 18  2025-04-16  {'codigoMoneda': 'JPY', 'descripcion': 'YENS',...
# 19  2025-04-16  {'codigoMoneda': 'MXP', 'descripcion': 'PESO M...
# 20  2025-04-16  {'codigoMoneda': 'NIO', 'descripcion': 'CORDOB...
# 21  2025-04-16  {'codigoMoneda': 'NOK', 'descripcion': 'CORONA...
# 22  2025-04-16  {'codigoMoneda': 'NZD', 'descripcion': 'DOLAR ...
# 23  2025-04-16  {'codigoMoneda': 'PEN', 'descripcion': 'SOLES'...
# 24  2025-04-16  {'codigoMoneda': 'PYG', 'descripcion': 'GUARAN...
# 25  2025-04-16  {'codigoMoneda': 'REF', 'descripcion': 'DOLAR ...
# 26  2025-04-16  {'codigoMoneda': 'RSD', 'descripcion': 'DINAR ...
# 27  2025-04-16  {'codigoMoneda': 'RUB', 'descripcion': 'RUSIA'...
# 28  2025-04-16  {'codigoMoneda': 'SEK', 'descripcion': 'CORONA...
# 29  2025-04-16  {'codigoMoneda': 'SGD', 'descripcion': 'DOLAR ...
# 30  2025-04-16  {'codigoMoneda': 'TRY', 'descripcion': 'LIRA T...
# 31  2025-04-16  {'codigoMoneda': 'USD', 'descripcion': 'DOLAR ...
# 32  2025-04-16  {'codigoMoneda': 'UYU', 'descripcion': 'PESO U...
# 33  2025-04-16  {'codigoMoneda': 'VEB', 'descripcion': 'BOLIVA...
# 34  2025-04-16  {'codigoMoneda': 'VND', 'descripcion': 'DONG V...
# 35  2025-04-16  {'codigoMoneda': 'XAG', 'descripcion': 'PLATA ...
# 36  2025-04-16  {'codigoMoneda': 'XAU', 'descripcion': 'ORO FI...
# 37  2025-04-16  {'codigoMoneda': 'XDR', 'descripcion': 'DEG', ...
# 38  2025-04-16  {'codigoMoneda': 'ZAR', 'descripcion': 'RAND S...

# %%
detalle_df = pd.json_normalize(conv_df_alt['detalle'])
detalle_df
# Out:
#    codigoMoneda                      descripcion     tipoPase  tipoCotizacion
# 0           ARS                             PESO     0.000881        0.000000
# 1           AUD                  DOLAR AUSTRALIA     0.636200      722.087000
# 2           AWG     FLORIN (ANTILLAS HOLANDESAS)     0.558659      634.078212
# 3           BOB                       BOLIVIANOS     0.145159      164.755407
# 4           BRL                             REAL     0.170413      193.418653
# 5           CAD                  DOLAR CANADIEN.     0.719683      816.840590
# 6           CHF                     FRANCO SUIZO     1.226392     1391.954869
# 7           CLP                     PESO CHILENO     0.001031        1.169633
# 8           CNH      YUAN CNH RENMINBI OFF SHORE     0.136919      155.402815
# 9           CNY                YUAN CNY RENMINBI     0.136996      155.490102
# 10          COP                      COLOMBIANOS     0.000232        0.263600
# 11          CZK                   CORONAS CHECAS     0.045475       51.614370
# 12          DKK                  CORONAS DANESAS     0.152325      172.889153
# 13          EUR                             EURO     1.137500     1291.062500
# 14          GBP                  LIBRA ESTERLINA     1.321800     1500.243000
# 15          HKD                  DOLAR HONG KONG     0.128864      146.261002
# 16          ILS                    LIBRA ISRAELI     0.271098      307.696478
# 17          INR                    RUPIA (INDIA)     0.011671       13.246192
# 18          JPY                             YENS     0.007023        7.971065
# 19          MXP                    PESO MEXICANO     0.050005       56.755676
# 20          NIO             CORDOBA NICARAGUENSE     0.027170       30.837447
# 21          NOK                  CORONAS NORUEGA     0.094387      107.129036
# 22          NZD                DOLAR NEOZELANDES     0.591400      671.239000
# 23          PEN                            SOLES     0.267917      304.085733
# 24          PYG                        GUARANIES     0.000125        0.141746
# 25          REF        DOLAR REFERENCIA COM 3500     0.000000     1172.833300
# 26          RSD                     DINAR SERBIA     0.009702       11.011464
# 27          RUB                            RUSIA     0.012046       13.672294
# 28          SEK                   CORONAS SUECAS     0.102219      116.018767
# 29          SGD                DOLAR DE SINGAPUR     0.762079      864.959610
# 30          TRY                       LIRA TURCA     0.026230       29.771195
# 31          USD                   DOLAR E.E.U.U.     0.000000     1135.000000
# 32          UYU                    PESO URUGUAYO     0.023643       26.835323
# 33          VEB                        BOLIVARES     0.012553       14.247267
# 34          VND  DONG VIETNAM (C/1.000 UNIDADES)     0.038694       43.917350
# 35          XAG                PLATA - ONZA TROY    32.803300        0.000000
# 36          XAU                ORO FINO (1 ONZA)  3327.380000        0.000000
# 37          XDR                              DEG     1.354730     1537.618550
# 38          ZAR                         RAND SUD     0.053057       60.219869

# %%
conv_df_alt = pd.concat([conv_df_alt['fecha'], detalle_df], axis=1)
conv_df_alt
# Out:
#          fecha codigoMoneda                      descripcion     tipoPase  \
# 0   2025-04-16          ARS                             PESO     0.000881
# 1   2025-04-16          AUD                  DOLAR AUSTRALIA     0.636200
# 2   2025-04-16          AWG     FLORIN (ANTILLAS HOLANDESAS)     0.558659
# 3   2025-04-16          BOB                       BOLIVIANOS     0.145159
# 4   2025-04-16          BRL                             REAL     0.170413
# 5   2025-04-16          CAD                  DOLAR CANADIEN.     0.719683
# 6   2025-04-16          CHF                     FRANCO SUIZO     1.226392
# 7   2025-04-16          CLP                     PESO CHILENO     0.001031
# 8   2025-04-16          CNH      YUAN CNH RENMINBI OFF SHORE     0.136919
# 9   2025-04-16          CNY                YUAN CNY RENMINBI     0.136996
# 10  2025-04-16          COP                      COLOMBIANOS     0.000232
# 11  2025-04-16          CZK                   CORONAS CHECAS     0.045475
# 12  2025-04-16          DKK                  CORONAS DANESAS     0.152325
# 13  2025-04-16          EUR                             EURO     1.137500
# 14  2025-04-16          GBP                  LIBRA ESTERLINA     1.321800
# 15  2025-04-16          HKD                  DOLAR HONG KONG     0.128864
# 16  2025-04-16          ILS                    LIBRA ISRAELI     0.271098
# 17  2025-04-16          INR                    RUPIA (INDIA)     0.011671
# 18  2025-04-16          JPY                             YENS     0.007023
# 19  2025-04-16          MXP                    PESO MEXICANO     0.050005
# 20  2025-04-16          NIO             CORDOBA NICARAGUENSE     0.027170
# 21  2025-04-16          NOK                  CORONAS NORUEGA     0.094387
# 22  2025-04-16          NZD                DOLAR NEOZELANDES     0.591400
# 23  2025-04-16          PEN                            SOLES     0.267917
# 24  2025-04-16          PYG                        GUARANIES     0.000125
# 25  2025-04-16          REF        DOLAR REFERENCIA COM 3500     0.000000
# 26  2025-04-16          RSD                     DINAR SERBIA     0.009702
# 27  2025-04-16          RUB                            RUSIA     0.012046
# 28  2025-04-16          SEK                   CORONAS SUECAS     0.102219
# 29  2025-04-16          SGD                DOLAR DE SINGAPUR     0.762079
# 30  2025-04-16          TRY                       LIRA TURCA     0.026230
# 31  2025-04-16          USD                   DOLAR E.E.U.U.     0.000000
# 32  2025-04-16          UYU                    PESO URUGUAYO     0.023643
# 33  2025-04-16          VEB                        BOLIVARES     0.012553
# 34  2025-04-16          VND  DONG VIETNAM (C/1.000 UNIDADES)     0.038694
# 35  2025-04-16          XAG                PLATA - ONZA TROY    32.803300
# 36  2025-04-16          XAU                ORO FINO (1 ONZA)  3327.380000
# 37  2025-04-16          XDR                              DEG     1.354730
# 38  2025-04-16          ZAR                         RAND SUD     0.053057
#
#     tipoCotizacion
# 0         0.000000
# 1       722.087000
# 2       634.078212
# 3       164.755407
# 4       193.418653
# 5       816.840590
# 6      1391.954869
# 7         1.169633
# 8       155.402815
# 9       155.490102
# 10        0.263600
# 11       51.614370
# 12      172.889153
# 13     1291.062500
# 14     1500.243000
# 15      146.261002
# 16      307.696478
# 17       13.246192
# 18        7.971065
# 19       56.755676
# 20       30.837447
# 21      107.129036
# 22      671.239000
# 23      304.085733
# 24        0.141746
# 25     1172.833300
# 26       11.011464
# 27       13.672294
# 28      116.018767
# 29      864.959610
# 30       29.771195
# 31     1135.000000
# 32       26.835323
# 33       14.247267
# 34       43.917350
# 35        0.000000
# 36        0.000000
# 37     1537.618550
# 38       60.219869

# %% [markdown]
# Ahora hacemos la misma llamada en un ciclo *for* para distintas fechas:

# %%
url = "https://api.bcra.gob.ar/estadisticascambiarias/v1.0/Cotizaciones"
fechas = [
            "2025-04-16"
            ,"2025-04-15"
            ,"2025-04-14"
        ]
resultados = pd.DataFrame(columns = ['fecha', 'codigoMoneda', 'descripcion', 'tipoPase', 'tipoCotizacion'])

for fecha in fechas:
    params = {"fecha": fecha}
    response = requests.get(url, params=params, verify=False)

    if response.status_code == 200:
        df = pd.DataFrame(response.json()['results']['detalle'])
        df['fecha'] = fecha
        #df = df[['fecha', 'codigoMoneda', 'descripcion', 'tipoPase', 'tipoCotizacion']]
        resultados = pd.concat([resultados, df], axis=0)
    else:
        print(f"Error: {response.status_code}")
# Out:
# c:\Users\Estefano\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.bcra.gob.ar'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# C:\Users\Estefano\AppData\Local\Temp\ipykernel_46072\4162985787.py:17: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   resultados = pd.concat([resultados, df], axis=0)
# c:\Users\Estefano\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.bcra.gob.ar'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# c:\Users\Estefano\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.bcra.gob.ar'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(

# %%
resultados[ resultados['fecha'] == '2025-04-16' ]
# Out:
#          fecha codigoMoneda                      descripcion     tipoPase  \
# 0   2025-04-16          ARS                             PESO     0.000881
# 1   2025-04-16          AUD                  DOLAR AUSTRALIA     0.636200
# 2   2025-04-16          AWG     FLORIN (ANTILLAS HOLANDESAS)     0.558659
# 3   2025-04-16          BOB                       BOLIVIANOS     0.145159
# 4   2025-04-16          BRL                             REAL     0.170413
# 5   2025-04-16          CAD                  DOLAR CANADIEN.     0.719683
# 6   2025-04-16          CHF                     FRANCO SUIZO     1.226392
# 7   2025-04-16          CLP                     PESO CHILENO     0.001031
# 8   2025-04-16          CNH      YUAN CNH RENMINBI OFF SHORE     0.136919
# 9   2025-04-16          CNY                YUAN CNY RENMINBI     0.136996
# 10  2025-04-16          COP                      COLOMBIANOS     0.000232
# 11  2025-04-16          CZK                   CORONAS CHECAS     0.045475
# 12  2025-04-16          DKK                  CORONAS DANESAS     0.152325
# 13  2025-04-16          EUR                             EURO     1.137500
# 14  2025-04-16          GBP                  LIBRA ESTERLINA     1.321800
# 15  2025-04-16          HKD                  DOLAR HONG KONG     0.128864
# 16  2025-04-16          ILS                    LIBRA ISRAELI     0.271098
# 17  2025-04-16          INR                    RUPIA (INDIA)     0.011671
# 18  2025-04-16          JPY                             YENS     0.007023
# 19  2025-04-16          MXP                    PESO MEXICANO     0.050005
# 20  2025-04-16          NIO             CORDOBA NICARAGUENSE     0.027170
# 21  2025-04-16          NOK                  CORONAS NORUEGA     0.094387
# 22  2025-04-16          NZD                DOLAR NEOZELANDES     0.591400
# 23  2025-04-16          PEN                            SOLES     0.267917
# 24  2025-04-16          PYG                        GUARANIES     0.000125
# 25  2025-04-16          REF        DOLAR REFERENCIA COM 3500     0.000000
# 26  2025-04-16          RSD                     DINAR SERBIA     0.009702
# 27  2025-04-16          RUB                            RUSIA     0.012046
# 28  2025-04-16          SEK                   CORONAS SUECAS     0.102219
# 29  2025-04-16          SGD                DOLAR DE SINGAPUR     0.762079
# 30  2025-04-16          TRY                       LIRA TURCA     0.026230
# 31  2025-04-16          USD                   DOLAR E.E.U.U.     0.000000
# 32  2025-04-16          UYU                    PESO URUGUAYO     0.023643
# 33  2025-04-16          VEB                        BOLIVARES     0.012553
# 34  2025-04-16          VND  DONG VIETNAM (C/1.000 UNIDADES)     0.038694
# 35  2025-04-16          XAG                PLATA - ONZA TROY    32.803300
# 36  2025-04-16          XAU                ORO FINO (1 ONZA)  3327.380000
# 37  2025-04-16          XDR                              DEG     1.354730
# 38  2025-04-16          ZAR                         RAND SUD     0.053057
#
#     tipoCotizacion
# 0         0.000000
# 1       722.087000
# 2       634.078212
# 3       164.755407
# 4       193.418653
# 5       816.840590
# 6      1391.954869
# 7         1.169633
# 8       155.402815
# 9       155.490102
# 10        0.263600
# 11       51.614370
# 12      172.889153
# 13     1291.062500
# 14     1500.243000
# 15      146.261002
# 16      307.696478
# 17       13.246192
# 18        7.971065
# 19       56.755676
# 20       30.837447
# 21      107.129036
# 22      671.239000
# 23      304.085733
# 24        0.141746
# 25     1172.833300
# 26       11.011464
# 27       13.672294
# 28      116.018767
# 29      864.959610
# 30       29.771195
# 31     1135.000000
# 32       26.835323
# 33       14.247267
# 34       43.917350
# 35        0.000000
# 36        0.000000
# 37     1537.618550
# 38       60.219869

# %%
resultados.to_csv("resultados/bcra_conversion.csv")

# %% [markdown]
# ## 4. Obtener datos de clima y guardarlos en un json (tratar convirtiendo la data a un DataFrame antes, y luego sin hacer esto)

# %%
# Coordenadas de algunas ciudades argentinas
ciudades = {
    "Buenos Aires": (-34.61, -58.38),
    "Córdoba": (-31.42, -64.18),
    "Mendoza": (-32.89, -68.84),
    "Rosario": (-32.95, -60.66),
    "Salta": (-24.78, -65.41)
}

# %%
url = "https://api.open-meteo.com/v1/forecast"
params = {
        "latitude": ciudades["Buenos Aires"][0],
        "longitude": ciudades["Buenos Aires"][1],
        "current_weather": "true"
    }

response = requests.get(url, params=params, verify=False)

if response.status_code == 200:
    print(response.json())
else:
    print(f"Error: {response.status_code}")
# Out:
# c:\Users\Estefano\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py:1097: InsecureRequestWarning: Unverified HTTPS request is being made to host 'api.open-meteo.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# {'latitude': -34.625, 'longitude': -58.5, 'generationtime_ms': 0.026106834411621094, 'utc_offset_seconds': 0, 'timezone': 'GMT', 'timezone_abbreviation': 'GMT', 'elevation': 37.0, 'current_weather_units': {'time': 'iso8601', 'interval': 'seconds', 'temperature': '°C', 'windspeed': 'km/h', 'winddirection': '°', 'is_day': '', 'weathercode': 'wmo code'}, 'current_weather': {'time': '2025-04-21T12:15', 'interval': 900, 'temperature': 13.0, 'windspeed': 3.3, 'winddirection': 13, 'is_day': 1, 'weathercode': 1}}

# %%
response.json()["current_weather"]
# Out:
# {'time': '2025-04-21T12:15',
#  'interval': 900,
#  'temperature': 13.0,
#  'windspeed': 3.3,
#  'winddirection': 13,
#  'is_day': 1,
#  'weathercode': 1}

# %%
datos_clima_lista = []

# Recorremos cada ciudad y consultamos la API
for ciudad, (lat, lon) in ciudades.items():
    url = "https://api.open-meteo.com/v1/forecast"
    params = {
        "latitude": lat,
        "longitude": lon,
        "current_weather": "true"
    }
    response = requests.get(url, params=params)

    if response.status_code == 200:
        datos_clima = response.json()["current_weather"]
        datos_clima["ciudad"] = ciudad
        datos_clima_lista.append(datos_clima)
    else:
        print(f"Error al obtener datos para {ciudad}: {response.status_code}")

# %%
clima_df = pd.DataFrame(datos_clima_lista)
clima_df
# Out:
#                time  interval  temperature  windspeed  winddirection  is_day  \
# 0  2025-04-21T12:15       900         13.0        3.3             13       1
# 1  2025-04-21T12:15       900         11.5        4.3             24       1
# 2  2025-04-21T12:15       900          9.9        4.4            189       1
# 3  2025-04-21T12:15       900         14.1        7.3             57       1
# 4  2025-04-21T12:15       900         13.9        3.1             45       1
#
#    weathercode        ciudad
# 0            1  Buenos Aires
# 1            1       Córdoba
# 2           45       Mendoza
# 3            2       Rosario
# 4           45         Salta

# %%
clima_df.to_json("resultados/clima_ciudades_desde_pandas.json", orient="records", indent=4, force_ascii=False)

# %%
import json

with open("resultados/clima_ciudades_desde_lista.json", "w", encoding="utf-8") as f:
    json.dump(datos_clima_lista, f, ensure_ascii=False, indent=4)
